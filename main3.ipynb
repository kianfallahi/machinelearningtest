# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %%
df.describe()
# Out:
#           Unnamed: 0           Year         Length  Market Share_total  \
# count  616656.000000  616656.000000  616656.000000       616656.000000
# mean   308328.500000    2017.381420       3.203963            3.011562
# std    178013.398136       0.751344       5.306656            4.919562
# min         1.000000    2016.000000       0.000000            0.000000
# 25%    154164.750000    2017.000000       2.000000            0.400000
# 50%    308328.500000    2017.000000       2.000000            1.400000
# 75%    462492.250000    2018.000000       4.000000            3.400000
# max    616656.000000    2019.000000      92.000000           89.500000
#
#        Temperature in Montreal during episode
# count                           533312.000000
# mean                                 6.707428
# std                                 12.178492
# min                                -27.425000
# 25%                                 -1.562500
# 50%                                  6.450000
# 75%                                 17.050000
# max                                 34.950000

# %%
df.head()
# Out:
#    Unnamed: 0                     Episode  Station     Channel Type Season  \
# 0           1                Vidéoclips V  V Total  General Channel   Fall
# 1           2         Apollo dans l'frigo  V Total  General Channel   Fall
# 2           3               Infopublicité  V Total  General Channel   Fall
# 3           4                  Infos, Les  V Total  General Channel   Fall
# 4           5  Souper presque parfait, Un  V Total  General Channel   Fall
#
#    Year        Date Day of week           Start_time             End_time  \
# 0  2016  2016-08-29      Monday  2016-08-29 06:00:00  2016-08-29 08:00:00
# 1  2016  2016-08-29      Monday  2016-08-29 08:00:00  2016-08-29 08:30:00
# 2  2016  2016-08-29      Monday  2016-08-29 08:30:00  2016-08-29 09:00:00
# 3  2016  2016-08-29      Monday  2016-08-29 09:00:00  2016-08-29 10:00:00
# 4  2016  2016-08-29      Monday  2016-08-29 10:00:00  2016-08-29 10:30:00
#
#    Length                Name of show Name of episode  \
# 0       8                Vidéoclips V             NaN
# 1       2         Apollo dans l'frigo             NaN
# 2       2               Infopublicité             NaN
# 3       4                  Infos, Les             NaN
# 4       2  Souper presque parfait, Un             NaN
#
#                                             Genre First time or rerun  \
# 0                               Music Video Clips                  No
# 1   Informal Education and Recreation and Leisure                  No
# 2  Infomercials, Promotional and Corporate Videos                  No
# 3                                            News                  No
# 4                                Reality Programs                  No
#
#   # of episode in the season Movie? Game of the Canadiens during episode?  \
# 0                        Yes     No                                    No
# 1                        Yes     No                                    No
# 2                        Yes     No                                    No
# 3                        Yes     No                                    No
# 4                        Yes     No                                    No
#
#    Market Share_total  Temperature in Montreal during episode
# 0                 0.9                                  20.400
# 1                 0.5                                  19.125
# 2                 0.3                                  19.125
# 3                 1.7                                  18.125
# 4                 2.2                                  18.250

# %%
df.shape
# Out:
# (616656, 20)

# %%
#sns.heatmap(df.isna())

# %%
df = df.drop('Unnamed: 0', axis=1)
df.head()
# Out:
#                       Episode  Station     Channel Type Season  Year  \
# 0                Vidéoclips V  V Total  General Channel   Fall  2016
# 1         Apollo dans l'frigo  V Total  General Channel   Fall  2016
# 2               Infopublicité  V Total  General Channel   Fall  2016
# 3                  Infos, Les  V Total  General Channel   Fall  2016
# 4  Souper presque parfait, Un  V Total  General Channel   Fall  2016
#
#          Date Day of week           Start_time             End_time  Length  \
# 0  2016-08-29      Monday  2016-08-29 06:00:00  2016-08-29 08:00:00       8
# 1  2016-08-29      Monday  2016-08-29 08:00:00  2016-08-29 08:30:00       2
# 2  2016-08-29      Monday  2016-08-29 08:30:00  2016-08-29 09:00:00       2
# 3  2016-08-29      Monday  2016-08-29 09:00:00  2016-08-29 10:00:00       4
# 4  2016-08-29      Monday  2016-08-29 10:00:00  2016-08-29 10:30:00       2
#
#                  Name of show Name of episode  \
# 0                Vidéoclips V             NaN
# 1         Apollo dans l'frigo             NaN
# 2               Infopublicité             NaN
# 3                  Infos, Les             NaN
# 4  Souper presque parfait, Un             NaN
#
#                                             Genre First time or rerun  \
# 0                               Music Video Clips                  No
# 1   Informal Education and Recreation and Leisure                  No
# 2  Infomercials, Promotional and Corporate Videos                  No
# 3                                            News                  No
# 4                                Reality Programs                  No
#
#   # of episode in the season Movie? Game of the Canadiens during episode?  \
# 0                        Yes     No                                    No
# 1                        Yes     No                                    No
# 2                        Yes     No                                    No
# 3                        Yes     No                                    No
# 4                        Yes     No                                    No
#
#    Market Share_total  Temperature in Montreal during episode
# 0                 0.9                                  20.400
# 1                 0.5                                  19.125
# 2                 0.3                                  19.125
# 3                 1.7                                  18.125
# 4                 2.2                                  18.250

# %%
df = df.drop('Name of episode', axis=1)
df = df.dropna()

# %%
df['Season'].value_counts().index
# Out:
# Index(['Fall', 'Winter', 'Summer', 'Spring'], dtype='object')

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizerE = CountVectorizer()
vectorizerN = CountVectorizer()

# %%
E = vectorizerE.fit_transform(df['Episode'])
df['Episode'] = E.todense()

# %%
N = vectorizerN.fit_transform(df['Name of show'])
df['Name of show'] = N.todense()

# %%
d_station = df['Station'].value_counts().index
i_station = []
for i in range(len(d_station)):
    i_station.append(i)
d = dict(zip(d_station, i_station))
df['Station'] = df['Station'].map(d)

# %%
d_station = df['Channel Type'].value_counts().index
i_station = []
for i in range(len(d_station)):
    i_station.append(i)
d = dict(zip(d_station, i_station))
df['Channel Type'] = df['Channel Type'].map(d)

# %%
d_station = df['Season'].value_counts().index
i_station = []
for i in range(len(d_station)):
    i_station.append(i)
d = dict(zip(d_station, i_station))
df['Season'] = df['Season'].map(d)

# %%
d_station = df['Day of week'].value_counts().index
i_station = []
for i in range(len(d_station)):
    i_station.append(i)
d = dict(zip(d_station, i_station))
df['Day of week'] = df['Day of week'].map(d)

# %%
d_station = df['Genre'].value_counts().index
i_station = []
for i in range(len(d_station)):
    i_station.append(i)
d = dict(zip(d_station, i_station))
df['Genre'] = df['Genre'].map(d)

# %%
d_station = df['First time or rerun'].value_counts().index
i_station = []
for i in range(len(d_station)):
    i_station.append(i)
d = dict(zip(d_station, i_station))
df['First time or rerun'] = df['First time or rerun'].map(d)

# %%
d_station = df['# of episode in the season'].value_counts().index
i_station = []
for i in range(len(d_station)):
    i_station.append(i)
d = dict(zip(d_station, i_station))
df['# of episode in the season'] = df['# of episode in the season'].map(d)

# %%
d_station = df['Movie?'].value_counts().index
i_station = []
for i in range(len(d_station)):
    i_station.append(i)
d = dict(zip(d_station, i_station))
df['Movie?'] = df['Movie?'].map(d)

# %%
d_station = df['Game of the Canadiens during episode?'].value_counts().index
i_station = []
for i in range(len(d_station)):
    i_station.append(i)
d = dict(zip(d_station, i_station))
df['Game of the Canadiens during episode?'] = df['Game of the Canadiens during episode?'].map(d)

# %%
df['Date'].replace(regex=True,inplace=True,to_replace=r'-',value=r'')
df['Start_time'].replace(regex=True,inplace=True,to_replace=r'-',value=r'')
df['End_time'].replace(regex=True,inplace=True,to_replace=r'-',value=r'')

df['Start_time'].replace(regex=True,inplace=True,to_replace=r':',value=r'')
df['End_time'].replace(regex=True,inplace=True,to_replace=r':',value=r'')

df['Start_time'].replace(regex=True,inplace=True,to_replace=r' ',value=r'')
df['End_time'].replace(regex=True,inplace=True,to_replace=r' ',value=r'')

# %%
df.head()
# Out:
#    Episode  Station  Channel Type  Season  Year      Date  Day of week  \
# 0        0       16             1       0  2016  20160829            2
# 1        0       16             1       0  2016  20160829            2
# 2        0       16             1       0  2016  20160829            2
# 3        0       16             1       0  2016  20160829            2
# 4        0       16             1       0  2016  20160829            2
#
#        Start_time        End_time  Length  Name of show  Genre  \
# 0  20160829060000  20160829080000       8             0     25
# 1  20160829080000  20160829083000       2             0      5
# 2  20160829083000  20160829090000       2             0     14
# 3  20160829090000  20160829100000       4             0      2
# 4  20160829100000  20160829103000       2             0      1
#
#    First time or rerun  # of episode in the season  Movie?  \
# 0                    0                           0       0
# 1                    0                           0       0
# 2                    0                           0       0
# 3                    0                           0       0
# 4                    0                           0       0
#
#    Game of the Canadiens during episode?  Market Share_total  \
# 0                                      0                 0.9
# 1                                      0                 0.5
# 2                                      0                 0.3
# 3                                      0                 1.7
# 4                                      0                 2.2
#
#    Temperature in Montreal during episode
# 0                                  20.400
# 1                                  19.125
# 2                                  19.125
# 3                                  18.125
# 4                                  18.250

# %%
df = df.dropna()

y = df['Market Share_total']
x = df.drop('Market Share_total', axis=1)

from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler(feature_range = (0, 1))
x = min_max_scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.05, random_state=101)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators=100)

# %%
model.fit(x_train, y_train)

# %%
from sklearn.metrics import r2_score
y_pred = model.predict(x_test)
r = r2_score(y_test, y_pred)
print(r)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(y_test, y_pred)
print(mae)
